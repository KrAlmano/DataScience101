# %%
import pandas as pd
import seaborn as sns
s = pd.Series([1,2,3,4,5])
print(type(s))
print(s.index)
print(s.size)
print(s.ndim)
print(s.values)
print(type(s.values))
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex(start=0, stop=5, step=1)
# 5
# 1
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
df = pd.read_csv("advertising.csv")
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
df = sns.load_dataset("titanic")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
df.isnull().values.any()
# Out:
# np.True_

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
#Seçim İşlemleri
df[0:13]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
df.drop(0,axis=0).head()  #0. indexi sildik
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
#Çoklu index silmek için
delete_indexes = [1,3,5,7]
df.drop(delete_indexes,axis=0).head(10) #Kalıcı değil bir değişkene atamadığımız sürece

#df.drop(delete_indexes,axis=0,inplace = True)  İnplace bunu atamasak bile kalıcı hale getirir
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# ...

# %%
#Değişkeni İndexe Çevirme
df.index = df["age"]
df.drop("age",axis=1).head(5)
# Out:
#       survived  pclass     sex  sibsp  parch     fare embarked  class    who  \
# age
# 22.0         0       3    male      1      0   7.2500        S  Third    man
# 38.0         1       1  female      1      0  71.2833        C  First  woman
# 26.0         1       3  female      0      0   7.9250        S  Third  woman
# 35.0         1       1  female      1      0  53.1000        S  First  woman
# 35.0         0       3    male      0      0   8.0500        S  Third    man
#
#       adult_male deck  embark_town alive  alone
# age
# 22.0        True  NaN  Southampton    no  False
# 38.0       False    C    Cherbourg   yes  False
# 26.0       False  NaN  Southampton   yes   True
# 35.0       False    C  Southampton   yes  False
# 35.0        True  NaN  Southampton    no   True

# %%
#İndexi değişkene çevirme
df.drop("age",axis=1,inplace=True)
df.head()
# Out:
#       survived  pclass     sex  sibsp  parch     fare embarked  class    who  \
# age
# 22.0         0       3    male      1      0   7.2500        S  Third    man
# 38.0         1       1  female      1      0  71.2833        C  First  woman
# 26.0         1       3  female      0      0   7.9250        S  Third  woman
# 35.0         1       1  female      1      0  53.1000        S  First  woman
# 35.0         0       3    male      0      0   8.0500        S  Third    man
#
#       adult_male deck  embark_town alive  alone
# age
# 22.0        True  NaN  Southampton    no  False
# 38.0       False    C    Cherbourg   yes  False
# 26.0       False  NaN  Southampton   yes   True
# 35.0       False    C  Southampton   yes  False
# 35.0        True  NaN  Southampton    no   True

# %%
#1. Yol
df["age"]=df.index
df.head()
# Out:
#       survived  pclass     sex  sibsp  parch     fare embarked  class    who  \
# age
# 22.0         0       3    male      1      0   7.2500        S  Third    man
# 38.0         1       1  female      1      0  71.2833        C  First  woman
# 26.0         1       3  female      0      0   7.9250        S  Third  woman
# 35.0         1       1  female      1      0  53.1000        S  First  woman
# 35.0         0       3    male      0      0   8.0500        S  Third    man
#
#       adult_male deck  embark_town alive  alone   age
# age
# 22.0        True  NaN  Southampton    no  False  22.0
# 38.0       False    C    Cherbourg   yes  False  38.0
# 26.0       False  NaN  Southampton   yes   True  26.0
# 35.0       False    C  Southampton   yes  False  35.0
# 35.0        True  NaN  Southampton    no   True  35.0

# %%
#2. Yol
df = df.reset_index()
df.head()
# Out:
#    index   age  survived  pclass     sex  sibsp  parch     fare embarked  \
# 0      0  22.0         0       3    male      1      0   7.2500        S
# 1      1  38.0         1       1  female      1      0  71.2833        C
# 2      2  26.0         1       3  female      0      0   7.9250        S
# 3      3  35.0         1       1  female      1      0  53.1000        S
# 4      4  35.0         0       3    male      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
df[["age","sex"]].head(5)
# Out:
#     age     sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
col_names=["fare","class","alive"]
df[col_names].head(5)
# Out:
#       fare  class alive
# 0   7.2500  Third    no
# 1  71.2833  First   yes
# 2   7.9250  Third   yes
# 3  53.1000  First   yes
# 4   8.0500  Third    no

# %%
df["age2"] = df["age"]**2
df["age2"].head(5)
# Out:
# 0     484.0
# 1    1444.0
# 2     676.0
# 3    1225.0
# 4    1225.0
# Name: age2, dtype: float64

# %%
df["age3"] = df["age"]/df["age2"]
df.head(5)
# Out:
#    index   age  survived  pclass     sex  sibsp  parch     fare embarked  \
# 0      0  22.0         0       3    male      1      0   7.2500        S
# 1      1  38.0         1       1  female      1      0  71.2833        C
# 2      2  26.0         1       3  female      0      0   7.9250        S
# 3      3  35.0         1       1  female      1      0  53.1000        S
# 4      4  35.0         0       3    male      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone    age2      age3
# 0  Third    man        True  NaN  Southampton    no  False   484.0  0.045455
# 1  First  woman       False    C    Cherbourg   yes  False  1444.0  0.026316
# 2  Third  woman       False  NaN  Southampton   yes   True   676.0  0.038462
# 3  First  woman       False    C  Southampton   yes  False  1225.0  0.028571
# 4  Third    man        True  NaN  Southampton    no   True  1225.0  0.028571

# %%
df.drop("age3",axis=1).head(3)
# Out:
#    index   age  survived  pclass     sex  sibsp  parch     fare embarked  \
# 0      0  22.0         0       3    male      1      0   7.2500        S
# 1      1  38.0         1       1  female      1      0  71.2833        C
# 2      2  26.0         1       3  female      0      0   7.9250        S
#
#    class    who  adult_male deck  embark_town alive  alone    age2
# 0  Third    man        True  NaN  Southampton    no  False   484.0
# 1  First  woman       False    C    Cherbourg   yes  False  1444.0
# 2  Third  woman       False  NaN  Southampton   yes   True   676.0

# %%
df.loc[:,df.columns.str.contains("age")].head()
# Out:
#     age    age2      age3
# 0  22.0   484.0  0.045455
# 1  38.0  1444.0  0.026316
# 2  26.0   676.0  0.038462
# 3  35.0  1225.0  0.028571
# 4  35.0  1225.0  0.028571

# %%
df.loc[:,~df.columns.str.contains("age")].head() # ~ işareti "age" dışındaki kolonları getir anlamına geliyor
# Out:
#    index  survived  pclass     sex  sibsp  parch     fare embarked  class  \
# 0      0         0       3    male      1      0   7.2500        S  Third
# 1      1         1       1  female      1      0  71.2833        C  First
# 2      2         1       3  female      0      0   7.9250        S  Third
# 3      3         1       1  female      1      0  53.1000        S  First
# 4      4         0       3    male      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.iloc[0:3]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
df.loc[0:3]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False

# %%
df.loc[0:3,"age"]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# Name: age, dtype: float64

# %%
df.iloc[0:3,0:3]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female
